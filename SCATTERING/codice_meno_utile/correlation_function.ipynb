# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('data/g_100.txt',sep='\t ',header=None,engine='python')
data.head()
# Out:
#           0         1    2    3    4
# 0  0.000025  52.58520  0.0  0.0  0.0
# 1  0.000050  47.91440  0.0  0.0  0.0
# 2  0.000075  36.87470  0.0  0.0  0.0
# 3  0.000100  11.19660  0.0  0.0  0.0
# 4  0.000125   3.79232  0.0  0.0  0.0

# %%
x = data[0]
y = data[1]

plt.plot(x,y)
plt.xscale('log')
# plt.yscale('log')
plt.xlim(0.01,10)
plt.ylim(0,0.1)
plt.show()

# %%
#rumors

row = pd.read_csv('data/I_100.txt',sep='\t ',header=None,engine='python')
row.head()
# Out:
#           0        1    2    3    4
# 0  0.117188  206.373  0.0  0.0  0.0
# 1  0.234375  198.338  0.0  0.0  0.0
# 2  0.351563  209.441  0.0  0.0  0.0
# 3  0.468750  205.760  0.0  0.0  0.0
# 4  0.585938  198.423  0.0  0.0  0.0

# %%
x = row[0]
y = row[1]

plt.plot(x,y)
plt.show()
