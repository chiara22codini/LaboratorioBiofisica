# %% [markdown]
# # la correlazione non è possibile, il dataset salvato considera solo le prime 150 acquisizioni

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import plotly

# %%
data = pd.read_csv('data/I_90.txt',sep='\t ',header=None,engine='python')
data.head()
# Out:
#           0        1    2    3    4
# 0  0.117188  140.323  0.0  0.0  0.0
# 1  0.234375  135.722  0.0  0.0  0.0
# 2  0.351563  138.065  0.0  0.0  0.0
# 3  0.468750  142.011  0.0  0.0  0.0
# 4  0.585938  145.368  0.0  0.0  0.0

# %%
x = data[0].to_numpy()
y = data[1].to_numpy()

avg_y = np.mean(y)
y = y - avg_y

plt.plot(x,y) # Khz
plt.show()

# %%
# y = np.concatenate([y,y,y,y,y])

def correlation_function(τ):
    num = np.sum(np.abs(y[:-τ]*y[τ:]))/len(y-τ)
    den = np.sum(y**2)/len(y)
    return num/den

# print(x,np.diff(x))

# def autocorrelation(y):
#     result = np.correlate(y, y, mode='full')
#     return result[result.size // 2:]

# autocorr_y = autocorrelation(y)
# plt.plot(autocorr_y)
# plt.show()

g2 = [correlation_function(τ) for τ in range(1,len(y))]

plt.plot(x[:-1],g2)
plt.show()
