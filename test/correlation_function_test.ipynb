# %% [markdown]
# NOT WORKING

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 100, 5000)
y = np.sin(x)

delta = np.random.normal(0, 0.1, x.shape)
delta = np.random.uniform(-0.1, 0.1, x.shape)
y += delta

plt.plot(x, y)
plt.show()

# %%
def g1_tau(y,tau):
    cross = np.sum(y[0:-tau]*y[tau:])/len(y)
    return cross / np.mean(y**2)

g1 = [g1_tau(y,tau) for tau in range(1,1000)]
plt.plot(g1)
plt.show()

# %%
fluctuation = np.diff(y)

g1 = [g1_tau(fluctuation,tau) for tau in range(1,1000)]
plt.plot(g1)
plt.show()
